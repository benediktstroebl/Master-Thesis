# %%
import requests
from requests.structures import CaseInsensitiveDict
from bs4 import BeautifulSoup
import json

# %%
url = "https://api.targomo.com/pointofinterest/reachability"

headers = CaseInsensitiveDict()
headers["Content-Type"] = "application/json"

data = """
{
  "sources": [
    {
      "id": "1",
      "lat": 52.511720,
      "lng": 13.322269,
      "tm": {
        "walk": {}
      }
    }
  ],
  "elevation": true,
  "maxEdgeWeight": 200,
  "edgeWeight": "distance",
  "osmTypes": [
    {
      "key": "landuse",
      "value": "commercial"
    },
    {
      "key": "landuse",
      "value": "construction"
    },
    {
      "key": "landuse",
      "value": "education"
    },
    {
      "key": "landuse",
      "value": "industrial"
    },
    {
      "key": "landuse",
      "value": "residential"
    },
    {
      "key": "landuse",
      "value": "retail"
    },
    {
      "key": "landuse",
      "value": "institutional"
    },
    {
      "key": "amenity",
      "value": "cafe"
    },
    {
      "key": "amenity",
      "value": "university"
    },
    {
      "key": "amenity",
      "value": "school"
    },
    {
      "key": "amenity",
      "value": "college"
    }
  ],
  "format": "geojson",
  "serviceUrl": "https://api.targomo.com/westcentraleurope/",
  "serviceKey": "BDVLQ87DL4MC63T3RANY"
}
"""

resp = requests.post(url, headers=headers, data=data)

# %%
parsed = json.loads(resp.text)
print(json.dumps(parsed, indent=4))
# Out:
# {
#     "type": "FeatureCollection",
#     "features": [
#         {
#             "type": "Feature",
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     13.322867,
#                     52.510851
#                 ]
#             },
#             "properties": {
#                 "closestSource": "1",
#                 "groupIds": [
#                     "cafe"
#                 ],
#                 "osmType": "amenity=cafe",
#                 "id": "0_618993715",
#                 "type": "node",
#                 "edgeWeight": 128,
#                 "clusterIds": [],
#                 "bounded": true,
#                 "tags": {
#                     "wheelchair": "limited",
#                     "amenity": "cafe",
#                     "name": "brot&butter",
#                     "opening_hours": "Mo-Fr 08:00-19:00; Sa 08:00-18:00"
#                 }
#             }
#         },
#         {
#             "type": "Feature",
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     13.322831,
#                     52.510606
#                 ]
#             },
#             "properties": {
#                 "closestSource": "1",
#                 "groupIds": [
#                     "cafe"
#                 ],
#                 "osmType": "amenity=cafe",
#                 "id": "0_3037805653",
#                 "type": "node",
#                 "edgeWeight": 157,
#                 "clusterIds": [],
#                 "bounded": true,
#                 "tags": {
#                     "owner": "Balzac Coffee GmbH",
#                     "wheelchair": "yes",
#                     "website": "https://de.espressohouse.com/coffee-shops/knesebeckstrae/",
#                     "amenity": "cafe",
#                     "addr:country": "DE",
#                     "addr:postcode": "10623",
#                     "addr:city": "Berlin",
#                     "addr:suburb": "Charlottenburg",
#                     "addr:housenumber": "2",
#                     "indoor_seating": "yes",
#                     "name": "Espresso House",
#                     "opening_hours": "Mo-Fr 07:00-20:00; Sa 08:00-20:00; Su, PH 08:00-19:00",
#                     "addr:street": "Knesebeckstra\u00dfe",
#                     "outdoor_seating": "yes"
#                 }
#             }
#         },
#         {
#             "type": "Feature",
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     13.322505,
#                     52.5111
#                 ]
#             },
#             "properties": {
#                 "closestSource": "1",
#                 "groupIds": [
#                     "cafe"
#                 ],
#                 "osmType": "amenity=cafe",
#                 "id": "0_1932625177",
#                 "type": "node",
#                 "edgeWeight": 100,
#                 "clusterIds": [],
#                 "bounded": true,
#                 "tags": {
#                     "wheelchair": "yes",
#                     "amenity": "cafe",
#                     "name": "Caras",
#                     "opening_hours": "Mo-Fr 07:30-19:00"
#                 }
#             }
#         }
#     ]
# }

# %%
soup = BeautifulSoup(resp.text, 'html.parser')
print(soup.prettify())
# Out:
# {"type":"FeatureCollection","features":[{"type":"Feature","geometry":{"type":"Point","coordinates":[13.322867,52.510851]},"properties":{"closestSource":"1","groupIds":["cafe"],"osmType":"amenity=cafe","id":"0_618993715","type":"node","edgeWeight":128,"clusterIds":[],"bounded":true,"tags":{"wheelchair":"limited","amenity":"cafe","name":"brot&amp;butter","opening_hours":"Mo-Fr 08:00-19:00; Sa 08:00-18:00"}}},{"type":"Feature","geometry":{"type":"Point","coordinates":[13.322831,52.510606]},"properties":{"closestSource":"1","groupIds":["cafe"],"osmType":"amenity=cafe","id":"0_3037805653","type":"node","edgeWeight":157,"clusterIds":[],"bounded":true,"tags":{"owner":"Balzac Coffee GmbH","wheelchair":"yes","website":"https://de.espressohouse.com/coffee-shops/knesebeckstrae/","amenity":"cafe","addr:country":"DE","addr:postcode":"10623","addr:city":"Berlin","addr:suburb":"Charlottenburg","addr:housenumber":"2","indoor_seating":"yes","name":"Espresso House","opening_hours":"Mo-Fr 07:00-20:00; Sa 08:00-20:00; Su, PH 08:00-19:00","addr:street":"Knesebeckstraße","outdoor_seating":"yes"}}},{"type":"Feature","geometry":{"type":"Point","coordinates":[13.322505,52.5111]},"properties":{"closestSource":"1","groupIds":["cafe"],"osmType":"amenity=cafe","id":"0_1932625177","type":"node","edgeWeight":100,"clusterIds":[],"bounded":true,"tags":{"wheelchair":"yes","amenity":"cafe","name":"Caras","opening_hours":"Mo-Fr 07:30-19:00"}}}]}
