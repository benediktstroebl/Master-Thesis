# %%
import requests

API_key = "AIzaSyCvxaRxdZsVkVqSJP2sI6UZKPnKNy_oAvw"

lon = 52.53202723843086
lat = 13.196961185376997

radius = 50

keyword = "company"

url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=" + str(lon) + "%2C" + str(lat) + "&radius=" + str(radius) + "&keyword=" + str(keyword) + "&key=" + API_key

payload={}
headers = {}

response = requests.request("GET", url, headers=headers, data=payload)

# %%
print(response.text)
# Out:
# {
#    "html_attributions" : [],
#    "results" : [
#       {
#          "business_status" : "OPERATIONAL",
#          "geometry" : {
#             "location" : {
#                "lat" : 52.5296359,
#                "lng" : 13.1987582
#             },
#             "viewport" : {
#                "northeast" : {
#                   "lat" : 52.53105832989272,
#                   "lng" : 13.19947452989272
#                },
#                "southwest" : {
#                   "lat" : 52.52835867010728,
#                   "lng" : 13.19677487010728
#                }
#             }
#          },
#          "icon" : "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png",
#          "icon_background_color" : "#7B9EB0",
#          "icon_mask_base_uri" : "https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet",
#          "name" : "Delloit",
#          "opening_hours" : {
#             "open_now" : true
#          },
#          "photos" : [
# ...
