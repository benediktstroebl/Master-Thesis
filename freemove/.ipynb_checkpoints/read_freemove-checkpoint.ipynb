# %%
import geopandas as gp
import movingpandas as mpd
from datetime import timedelta
from pyproj import CRS
import pandas as pd
from tqdm import tqdm
from joblib import Parallel, delayed
import logging
from shapely import Point
from datetime import datetime
logging.basicConfig(filename='log_read_freemove.log', level=logging.DEBUG)

# %%
print('Reading data...')
raw_points_gdf = gp.read_file('../data/freemove/raw_full.geojson', crs='EPSG:4326')
print('Data read.')
# Out:
# Reading data...
# Data read.

# %%
# create geojson of points
rows = []
for i, row in tqdm(raw_points_gdf.iterrows(), total=len(raw_points_gdf), miniters=10):
    person_id = row.PERSON_ID
    trip_id = row.TRIP_ID
    leg_id = row.LEG_ID
    leg_start = datetime.strptime(str(row.LEG_START), '%Y-%m-%dT%H:%M:%S')
    leg_end = datetime.strptime(str(row.LEG_END), '%Y-%m-%dT%H:%M:%S')
    trip_purpose_ids = row.TRIP_PURPOSE_IDS
    traffic_mode = row.TRAFFIC_MODE
    leg_len_in_mtrs = row.LEG_LEN_IN_MTRS
    leg_duration_in_secs = row.LEG_DURATION_IN_SECS

    # interpolate time of points of a leg since we only have start and end time
    total_points_of_leg = len(row.geometry.coords)
    interpolattion_increment = leg_duration_in_secs / total_points_of_leg

    for point_i, point in enumerate(row.geometry.coords):
        new_row = {"PERSON_ID": person_id, 
                   "TRIP_ID": trip_id, 
                   "LEG_ID": leg_id, 
                   "LEG_START": leg_start, 
                   "LEG_END": leg_end,
                   "TIME": leg_start + timedelta(seconds=round(interpolattion_increment * point_i, ndigits=0)),
                   "TRIP_PURPOSE_IDS": trip_purpose_ids, 
                   "TRAFFIC_MODE": traffic_mode, 
                   "LEG_LEN_IN_MTRS": leg_len_in_mtrs, 
                   "LEG_DURATION_IN_SECS": leg_duration_in_secs, 
                   "LAT": Point(point).y,
                   "LON": Point(point).x}
        rows.append(new_row)


raw_points_gdf = pd.DataFrame(rows)[["PERSON_ID", "TRIP_ID", "TIME", "LAT", "LON"]]
raw_points_gdf
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 4958/4958 [00:42<00:00, 115.99it/s]
#          PERSON_ID  TRIP_ID                TIME        LAT        LON
# 0            16348   985222 2022-10-31 09:15:57  52.454451  13.504967
# 1            16348   985222 2022-10-31 09:15:58  52.454463  13.504983
# 2            16348   985222 2022-10-31 09:15:59  52.454454  13.505009
# 3            16348   985222 2022-10-31 09:16:00  52.454422  13.505042
# 4            16348   985222 2022-10-31 09:16:01  52.454391  13.505098
# ...            ...      ...                 ...        ...        ...
# 1637556      17273  1012443 2022-11-15 10:00:46  52.501937  13.355693
# 1637557      17273  1012443 2022-11-15 10:00:47  52.501903  13.355708
# 1637558      17273  1012443 2022-11-15 10:00:48  52.501874  13.355723
# 1637559      17273  1012443 2022-11-15 10:00:49  52.501847  13.355738
# 1637560      17273  1012443 2022-11-15 10:00:50  52.501821  13.355753
#
# [1637561 rows x 5 columns]

# %%
# rename columns to match geolife point dataset
raw_points_gdf = raw_points_gdf.rename(columns={'TRIP_ID': 'traj_id', 
                                                'TIME': 'time', 
                                                'LON': 'lon',
                                                'LAT': 'lat',
                                                'PERSON_ID': 'user'}).reset_index(drop=True)

# %%
def write_geojson(gdf, path):
    assert isinstance(gdf, gp.GeoDataFrame)
    gdf.to_file(path, driver='GeoJSON')

# %%
print('removing points outside valid lon and lat range...')
# Remove points that fall outside the valid lon and lat range (-90 to 90 for latitude and -180 to 180 for longitude)
raw_points_gdf = raw_points_gdf[(raw_points_gdf.lat >= -90) & (raw_points_gdf.lat <= 90) & (raw_points_gdf.lon >= -180) & (raw_points_gdf.lon <= 180)]
print('points removed.')
# Out:
# removing points outside valid lon and lat range...
# points removed.

# %%
print('Dropping NA values...')
len_before = len(raw_points_gdf)
logging.info('Rows before dropping NA values: {}'.format(len(raw_points_gdf)))
raw_points_gdf.dropna(inplace=True)
logging.info('Rows after dropping NA values: {}'.format(len(raw_points_gdf)))
logging.info('Rows dropped: {}'.format(len_before - len(raw_points_gdf)))
print('NA values dropped.')
# Out:
# Dropping NA values...
# NA values dropped.

# %%
print('creating trajectory collection...')
# Create trajectory collection
raw_full_trip_collection = mpd.TrajectoryCollection(raw_points_gdf, traj_id_col='traj_id', obj_id_col ='user', t='time', x='lon', y='lat')
print('trajectory collection created.')

logging.info(f'This is a test log of traj id: {raw_full_trip_collection.trajectories[0].id}')
logging.info(f'Number of trajectories in data: {len(raw_full_trip_collection.trajectories)}')
# Out:
# creating trajectory collection...
# trajectory collection created.

# %%
# Convert to EPSG
def convert_epsg(traj):
    result = traj.to_crs(CRS(3035))
    result.obj_id = traj.obj_id
    return result
print('converting to EPSG:3035...')
raw_full_trip_collection.trajectories = Parallel(n_jobs=-2, verbose=10)(delayed(convert_epsg)(traj) for traj in raw_full_trip_collection.trajectories)
print('converted to EPSG:3035 (Berlin).')
# Out:
# converting to EPSG:3035...
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 127 concurrent workers.
# [Parallel(n_jobs=-2)]: Done  11 tasks      | elapsed:    5.3s
# [Parallel(n_jobs=-2)]: Done  34 tasks      | elapsed:    5.9s
# [Parallel(n_jobs=-2)]: Done  59 tasks      | elapsed:    6.6s
# [Parallel(n_jobs=-2)]: Done  84 tasks      | elapsed:    7.3s
# [Parallel(n_jobs=-2)]: Done 111 tasks      | elapsed:    8.4s
# [Parallel(n_jobs=-2)]: Done 138 tasks      | elapsed:    9.0s
# [Parallel(n_jobs=-2)]: Done 167 tasks      | elapsed:    9.9s
# [Parallel(n_jobs=-2)]: Done 196 tasks      | elapsed:   10.9s
# [Parallel(n_jobs=-2)]: Done 227 tasks      | elapsed:   11.5s
# [Parallel(n_jobs=-2)]: Done 258 tasks      | elapsed:   12.1s
# [Parallel(n_jobs=-2)]: Done 291 tasks      | elapsed:   12.9s
# [Parallel(n_jobs=-2)]: Done 324 tasks      | elapsed:   13.6s
# [Parallel(n_jobs=-2)]: Done 359 tasks      | elapsed:   14.2s
# [Parallel(n_jobs=-2)]: Done 394 tasks      | elapsed:   15.0s
# [Parallel(n_jobs=-2)]: Done 431 tasks      | elapsed:   16.0s
# [Parallel(n_jobs=-2)]: Done 468 tasks      | elapsed:   16.9s
# [Parallel(n_jobs=-2)]: Done 507 tasks      | elapsed:   18.1s
# [Parallel(n_jobs=-2)]: Done 546 tasks      | elapsed:   19.1s
# [Parallel(n_jobs=-2)]: Done 587 tasks      | elapsed:   20.3s
# [Parallel(n_jobs=-2)]: Done 628 tasks      | elapsed:   21.3s
# [Parallel(n_jobs=-2)]: Done 671 tasks      | elapsed:   22.0s
# [Parallel(n_jobs=-2)]: Done 714 tasks      | elapsed:   23.1s
# [Parallel(n_jobs=-2)]: Done 759 tasks      | elapsed:   24.2s
# [Parallel(n_jobs=-2)]: Done 804 tasks      | elapsed:   25.4s
# [Parallel(n_jobs=-2)]: Done 851 tasks      | elapsed:   26.5s
# [Parallel(n_jobs=-2)]: Done 898 tasks      | elapsed:   27.5s
# [Parallel(n_jobs=-2)]: Done 947 tasks      | elapsed:   28.7s
# [Parallel(n_jobs=-2)]: Done 996 tasks      | elapsed:   30.0s
# [Parallel(n_jobs=-2)]: Done 1047 tasks      | elapsed:   31.8s
# [Parallel(n_jobs=-2)]: Done 1098 tasks      | elapsed:   33.1s
# [Parallel(n_jobs=-2)]: Done 1151 tasks      | elapsed:   34.4s
# [Parallel(n_jobs=-2)]: Done 1296 out of 1408 | elapsed:   38.6s remaining:    3.3s
# [Parallel(n_jobs=-2)]: Done 1408 out of 1408 | elapsed:   41.4s finished
# converted to EPSG:3035 (Berlin).

# %%
# Split trajectories

def split_traj(traj, MAX_DIAMETER=100, MIN_DURATION=timedelta(minutes=15), MIN_LENGTH=500):
    try:
        split = mpd.StopSplitter(traj).split(max_diameter=MAX_DIAMETER, min_duration=MIN_DURATION, min_length=MIN_LENGTH)
        for i in range(len(split.trajectories)):
            split.trajectories[i].obj_id = traj.obj_id
        return split.trajectories
    except BaseException as e:
        print(e, 'Error at traj: ', traj.id)
        logging.warning(f'{e} Error at traj: {traj.id}')

        return []

print('splitting trajectories...')
# split_trajs = Parallel(n_jobs=4, verbose=10)(delayed(split_traj)(traj) for traj in geolife_raw_collection.trajectories)
split_trajs = []
for traj in tqdm(raw_full_trip_collection.trajectories):
    try:
        split_trajs.append(split_traj(traj))
    except BaseException as e:
        print(e, 'Error at traj: ', traj.id)
        continue
    
split_trajs = [traj for sublist in split_trajs for traj in sublist]
freemove_splitted_collection = mpd.TrajectoryCollection(split_trajs)
print('trajectories split.')
# Out:
# splitting trajectories...
# 100%|█████████████████████████████████████████████████████████████████████████████| 1408/1408 [1:21:19<00:00,  3.47s/it]
# trajectories split.

# %%
# Smooth trajectories
def smooth_traj(traj, PROCESS_NOISE_STD=0.1, MEASUREMENT_NOISE_STD=10):
    try:
        result = mpd.KalmanSmootherCV(traj).smooth(process_noise_std=PROCESS_NOISE_STD, measurement_noise_std=MEASUREMENT_NOISE_STD)
        result.obj_id = traj.obj_id
        return result
    except BaseException as e:
        print(e, 'Error at traj: ', traj.id)
        logging.warning(f'{e} Error at traj: {traj.id}')
        return traj

print('smoothing trajectories...')
# geolife_splitted_smooth_collection = Parallel(n_jobs=4, verbose=10)(delayed(smooth_traj)(traj) for traj in geolife_splitted_collection.trajectories)
freemove_smooth_collection = []
for traj in tqdm(raw_full_trip_collection.trajectories):
    try:
        freemove_smooth_collection.append(smooth_traj(traj))
    except BaseException as e:
        print(e, 'Error at traj: ', traj.id)
        continue

freemove_smooth_collection = mpd.TrajectoryCollection(freemove_smooth_collection)
print('trajectories smoothed.')
# Out:
# smoothing trajectories...
# 100%|████████████████████████████████████████████████████████████████████████████| 1408/1408 [00:00<00:00, 31458.84it/s]
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  978933
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  978934
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  978946
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  978955
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  980322
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  985011
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  985073
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  985091
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  985112
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  985118
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  985127
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  985179
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  985191
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  985206
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  985207
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  985210
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  985222
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  985223
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  985257
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  985258
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  985280
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  985284
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  985285
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  985292
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  985293
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  985301
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  985302
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  985304
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  985308
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  985318
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  985326
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  985331
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  985336
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  985353
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  985360
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  985361
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  985398
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  985401
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  985402
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  985407
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  985445
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  985446
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  985451
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  985459
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  985467
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  985476
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  985480
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  985481
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  985493
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  985495
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  985506
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  985515
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  985523
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  985532
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  985550
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  985561
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  985576
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  985594
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  985595
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  985597
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  985605
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  985607
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  985608
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  985612
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  985627
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  985636
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  985637
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  985638
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  985639
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  985647
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  985648
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  985659
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  985664
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  985673
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  985700
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  985705
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  985709
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  985724
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  985734
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  985739
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  985753
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  985766
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  985767
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  985768
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  985769
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  985771
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  985772
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  985776
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  985784
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  985803
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  985804
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  985809
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  985820
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  985827
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  985828
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  985835
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  985847
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  985853
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  985854
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  985855
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  985864
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  985865
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  985877
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  985956
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  985957
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  985979
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  985988
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  985993
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  986084
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  986203
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  986574
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  986690
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  986780
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  986865
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  986866
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  987011
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  987053
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  987063
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  987076
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  987103
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  987112
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  987122
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  987231
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  987247
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  987270
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  987273
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  987275
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  987276
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  987277
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  987350
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  987381
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  987444
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  987507
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  987508
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  987540
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  987559
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  987587
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  987673
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  987708
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  987720
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  987731
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  987743
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  987764
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  987862
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  987873
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  987927
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  987931
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  987945
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  987951
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  987958
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  987965
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  987974
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  987987
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  988010
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  988021
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  988047
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  988109
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  988110
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  988113
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  988159
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  988177
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  988180
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  988202
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  988221
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  988233
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  988242
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  988251
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  988257
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  988258
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  988268
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  988300
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  988306
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  988311
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  988315
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  988316
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  988319
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  988320
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  988323
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  988324
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  988325
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  988335
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  988341
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  988354
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  988355
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  988358
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  988364
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  988369
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  988376
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  988387
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  988393
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  988401
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  988409
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  988411
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  988416
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  988417
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  988426
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  988434
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  988440
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  988461
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  988463
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  988486
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  988491
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  988492
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  988522
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  988523
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  988524
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  988525
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  988526
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  988537
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  988540
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  988541
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  988542
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  988543
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  988544
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  988584
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  988624
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  988661
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  988663
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  988748
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  988988
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  989009
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  989032
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  989059
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  989130
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  989164
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  989216
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  989226
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  989264
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  989306
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  989408
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  989417
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  989449
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  989450
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  989451
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  989522
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  989542
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  989548
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  989661
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  989662
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  989686
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  989808
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  989859
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  989887
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  989909
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  989939
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  989953
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  990034
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  990036
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  990138
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  990254
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  990272
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  990273
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  990326
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  990327
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  990328
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  990339
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  990341
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  990367
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  990381
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  990385
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  990392
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  990406
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  990497
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  990542
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  990560
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  990649
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  990663
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  990750
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  990764
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  990777
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  990948
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  991023
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  991040
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  991041
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  991057
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  991070
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  991094
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  991095
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  991130
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  991140
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  991151
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  991152
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  991153
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  991154
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  991155
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  991159
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  991168
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  991169
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  991175
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  991195
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  991218
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  991225
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  991377
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  991381
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  991386
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  991387
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  991388
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  991389
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  991390
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  991419
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  991470
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  991483
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  991499
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  991563
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  991612
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  991624
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  991679
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  991707
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  991750
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  991751
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  991764
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  991765
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  991766
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  991767
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  991782
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  991788
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  991789
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  991840
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  991980
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  992013
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  992014
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  992017
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  992058
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  992059
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  992075
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  992076
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  992093
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  992196
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  992207
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  992243
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  992244
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  992259
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  992263
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  992280
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  992299
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  992304
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  992329
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  992339
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  992345
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  992353
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  992357
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  992395
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  992398
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  992415
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  992416
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  992529
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  992535
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  992571
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  992588
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  992614
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  992640
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  992642
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  992651
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  992654
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  992655
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  992660
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  992701
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  992702
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  992708
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  992713
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  992721
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  992733
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  992734
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  992735
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  992752
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  992753
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  992828
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  992829
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  992839
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  992840
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  992841
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  992846
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  992872
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  992873
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  992884
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  992885
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  992891
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  992901
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  992902
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  992904
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  992909
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  992913
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  992916
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  992935
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  992941
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  992952
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  992968
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  992971
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  992974
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  992993
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  993000
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  993036
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  993040
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  993042
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  993052
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  993053
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  993057
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  993062
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  993077
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  993079
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  993089
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  993090
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  993091
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  993092
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  993098
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  993106
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  993128
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  993129
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  993154
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  993163
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  993164
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  993170
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  993171
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  993173
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  993183
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  993185
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  993216
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  993217
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  993218
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  993219
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  993227
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  993239
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  993240
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  993242
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  993273
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  993274
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  993280
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  993315
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  993317
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  993328
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  993350
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  993353
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  993354
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  993356
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  993358
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  993359
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  993363
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  993366
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  993373
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  993377
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  993402
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  993414
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  993419
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  993420
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  993421
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  993434
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  993466
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  993467
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  993470
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  993475
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  993476
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  993486
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  993487
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  993488
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  993489
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  993490
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  993491
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  993493
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  993494
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  993495
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  993496
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  993497
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  993498
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  993499
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  993500
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  993501
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  993510
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  993520
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  993521
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  993524
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  993535
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  993553
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  993609
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  993627
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  993651
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  993739
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  993797
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  993854
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  993926
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  993985
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  994016
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  994026
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  994046
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  994083
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  994185
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  994271
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  994272
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  994382
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  994383
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  994514
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  994525
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  994671
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  994676
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  994795
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  994847
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  994908
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  994920
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  994949
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  994971
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  995005
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  995006
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  995084
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  995136
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  995153
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  995155
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  995174
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  995217
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  995265
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  995266
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  995387
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  995408
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  995467
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  995531
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  995532
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  995585
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  995586
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  995587
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  995592
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  995593
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  995637
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  995871
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  995872
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  995913
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  995914
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  995915
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  995916
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  995917
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  995918
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  995919
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  995924
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  995925
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  995926
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  995927
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  995941
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  996155
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  996156
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  996180
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  996189
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  996190
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  996244
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  996255
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  996376
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  996380
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  996509
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  996560
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  996569
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  996585
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  996608
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  996616
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  996681
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  996744
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  997007
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  997008
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  997175
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  997212
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  997213
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  997260
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  997265
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  997294
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  997338
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  997339
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  997340
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  997360
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  997673
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  997733
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  997766
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  997767
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  997773
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  997790
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  997958
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  997959
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  997982
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  997999
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  998022
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  998105
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  998129
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  998144
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  998157
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  998178
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  998269
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  998270
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  998422
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  998470
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  998491
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  998502
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  998572
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  998628
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  998671
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  998672
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  998680
# ...
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  1010418
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  1010476
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  1010477
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  1010484
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  1010533
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  1010569
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  1010585
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  1010586
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  1010589
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  1010590
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  1010659
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  1010672
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  1010677
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  1010710
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  1010711
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  1010720
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  1010721
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  1010722
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  1010723
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  1010728
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  1010730
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  1010804
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  1010805
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  1010813
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  1010896
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  1010903
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  1010919
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  1010925
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  1010929
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  1010941
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  1010960
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  1010990
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  1011057
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  1011085
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  1011086
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  1011098
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  1011160
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  1011245
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  1011249
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  1011262
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  1011289
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  1011290
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  1011376
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  1011426
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  1011504
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  1011505
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  1011534
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  1011546
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  1011577
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  1011593
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  1011649
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  1011667
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  1011700
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  1011721
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  1011722
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  1011727
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  1011729
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  1011730
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  1011755
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  1011765
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  1011780
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  1011784
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  1011785
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  1011849
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  1011916
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  1011917
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  1011918
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  1011919
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  1011934
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  1011936
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  1012016
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  1012063
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  1012064
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  1012065
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  1012066
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  1012103
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  1012104
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  1012106
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  1012216
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  1012283
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  1012284
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  1012285
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  1012311
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  1012317
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  1012396
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  1012411
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  1012412
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  1012432
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  1012434
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  1012443
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  1012464
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  1012500
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  1012507
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  1012568
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  1012612
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  1012615
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  1012620
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  1012624
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  1012630
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  1012758
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  1012946
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  1012951
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  1012952
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  1012953
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  1013004
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  1013167
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  1013168
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  1013169
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  1013232
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  1013259
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  1013286
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  1013433
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  1013447
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  1013450
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  1013463
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  1013487
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  1013488
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  1013489
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  1013529
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  1013557
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  1013631
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  1013643
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  1013650
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  1013653
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  1013655
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  1013664
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  1013668
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  1013669
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  1013674
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  1013851
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  1013870
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  1014012
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  1014121
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  1014133
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  1014147
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  1014168
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  1014392
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  1014553
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  1014572
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  1014644
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  1014687
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  1014804
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  1014818
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  1014819
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  1014820
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  1014867
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  1014868
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  1014870
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  1014956
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  1014993
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  1015005
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  1015006
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  1015177
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  1015178
# module 'movingpandas' has no attribute 'KalmanSmootherCV' Error at traj:  1015191
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[19], line 22
#      19         print(e, 'Error at traj: ', traj.id)
#      20         continue
# ---> 22 freemove_smooth_collection = mpd.TrajectoryCollection(freemove_smooth_collection)
#      23 print('trajectories smoothed.')
#
# File /usr/local/lib/python3.8/dist-packages/movingpandas/trajectory_collection.py:61, in TrajectoryCollection.__init__(self, data, traj_id_col, obj_id_col, t, x, y, crs, min_length, min_duration)
#      59 self.min_duration = min_duration
#      60 if type(data) == list:
# ---> 61     self.trajectories = [
#      62         traj for traj in data if traj.get_length() >= min_length
#      63     ]
#      64     if min_duration:
#      65         self.trajectories = [
#      66             traj
#      67             for traj in self.trajectories
#      68             if traj.get_duration() >= min_duration
#      69         ]
#
# File /usr/local/lib/python3.8/dist-packages/movingpandas/trajectory_collection.py:62, in <listcomp>(.0)
#      59 self.min_duration = min_duration
#      60 if type(data) == list:
#      61     self.trajectories = [
# ---> 62         traj for traj in data if traj.get_length() >= min_length
#      63     ]
#      64     if min_duration:
#      65         self.trajectories = [
#      66             traj
#      67             for traj in self.trajectories
#      68             if traj.get_duration() >= min_duration
#      69         ]
#
# File /usr/local/lib/python3.8/dist-packages/movingpandas/trajectory.py:746, in Trajectory.get_length(self)
#     734 def get_length(self):
#     735     """
#     736     Return the length of the trajectory.
#     737
#    (...)
#     744         Length of the trajectory
#     745     """
# --> 746     pt_tuples = [(pt.y, pt.x) for pt in self.df.geometry.tolist()]
#     747     if self.is_latlon:
#     748         return geodesic(*pt_tuples).m
#
# File /usr/local/lib/python3.8/dist-packages/movingpandas/trajectory.py:746, in <listcomp>(.0)
#     734 def get_length(self):
#     735     """
#     736     Return the length of the trajectory.
#     737
#    (...)
#     744         Length of the trajectory
#     745     """
# --> 746     pt_tuples = [(pt.y, pt.x) for pt in self.df.geometry.tolist()]
#     747     if self.is_latlon:
#     748         return geodesic(*pt_tuples).m
#
# File /usr/local/lib/python3.8/dist-packages/shapely/geometry/point.py:88, in Point.x(self)
#      85 @property
#      86 def x(self):
#      87     """Return x coordinate."""
# ---> 88     return shapely.get_x(self)
#
# File /usr/local/lib/python3.8/dist-packages/shapely/decorators.py:77, in multithreading_enabled.<locals>.wrapped(*args, **kwargs)
#      75     for arr in array_args:
#      76         arr.flags.writeable = False
# ---> 77     return func(*args, **kwargs)
#      78 finally:
#      79     for arr, old_flag in zip(array_args, old_flags):
#
# File /usr/local/lib/python3.8/dist-packages/shapely/_geometry.py:271, in get_x(point, **kwargs)
#     247 @multithreading_enabled
#     248 def get_x(point, **kwargs):
#     249     """Returns the x-coordinate of a point
#     250
#     251     Parameters
#    (...)
#     269     nan
#     270     """
# --> 271     return lib.get_x(point, **kwargs)
#
# KeyboardInterrupt:

# %%
# Generalize trajectories
def generalize_traj(traj, TOLERANCE=1.0):
    try:
        result = mpd.DouglasPeuckerGeneralizer(traj).generalize(tolerance=TOLERANCE)
        result.obj_id = traj.obj_id
        return result
    except BaseException as e:
        print(e, 'Error at traj: ', traj.id)
        logging.warning(f'{e} Error at traj: {traj.id}')
        return traj

# Douglas-Peucker generalization for non-smoothed trajectories
print('generalizing trajectories... (1)')
logging.info('generalizing trajectories... (1)')
# geolife_splitted_generalized_collection = Parallel(n_jobs=4, verbose=10)(delayed(generalize_traj)(traj) for traj in geolife_splitted_collection.trajectories)
freemove_generalized_collection = []
for traj in tqdm(raw_full_trip_collection.trajectories):
    try:
        freemove_generalized_collection.append(generalize_traj(traj))
    except BaseException as e:
        print(e, 'Error at traj: ', traj.id)
        continue
freemove_generalized_collection = mpd.TrajectoryCollection(freemove_generalized_collection)
print('trajectories generalized. (1)')
logging.info('trajectories generalized. (1)')
# Out:
# generalizing trajectories... (1)
#  66%|█████████████████████████████████████████████████████▏                          | 936/1408 [03:33<02:07,  3.71it/s]
#  Error at traj:  1006129
#  68%|██████████████████████████████████████████████████████▎                         | 955/1408 [03:38<01:38,  4.61it/s]
#  Error at traj:  1006176
# 100%|███████████████████████████████████████████████████████████████████████████████| 1408/1408 [05:45<00:00,  4.08it/s]
# trajectories generalized. (1)

# %%
# Douglas-Peucker generalization for smoothed trajectories
print('generalizing trajectories... (2)')
logging.info('generalizing trajectories... (2)')
# geolife_splitted_smooth_generalized_collection = Parallel(n_jobs=4, verbose=10)(delayed(generalize_traj)(traj) for traj in geolife_splitted_smooth_collection.trajectories)
freemove_smooth_generalized_collection = []
for traj in tqdm(freemove_smooth_collection.trajectories):
    try:
        freemove_smooth_generalized_collection.append(generalize_traj(traj))
    except BaseException as e:
        print(e, 'Error at traj: ', traj.id)
        continue

freemove_smooth_generalized_collection = mpd.TrajectoryCollection(freemove_smooth_generalized_collection)
print('trajectories generalized. (2)')
logging.info('trajectories generalized. (2)')
# Out:
# generalizing trajectories... (2)
# 100%|███████████████████████████████████████████████████████████████████████████████| 1408/1408 [05:45<00:00,  4.07it/s]
# trajectories generalized. (2)

# %%
def convert_trajcollection_to_gdf(trajcollection):
    gdfs = []
    for traj in tqdm(trajcollection.trajectories):
        traj_gdf = traj.to_traj_gdf()
        traj_gdf['user_id'] = traj.obj_id
        gdfs.append(traj_gdf)

    gdf = gp.GeoDataFrame(pd.concat(gdfs), crs='EPSG:3035')

    return gp.GeoDataFrame(pd.concat(gdfs), crs='EPSG:3035')

# %%
logging.info('converting to gdf...')
freemove_raw = convert_trajcollection_to_gdf(raw_full_trip_collection)
freemove_splitted = convert_trajcollection_to_gdf(freemove_splitted_collection)
freemove_smooth = convert_trajcollection_to_gdf(freemove_smooth_collection)
freemove_generalized = convert_trajcollection_to_gdf(freemove_generalized_collection)
freemove_smooth_generalized = convert_trajcollection_to_gdf(freemove_smooth_generalized_collection)
logging.info('converted to gdf.')
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████| 1408/1408 [00:33<00:00, 41.97it/s]

# %%
# Write gdf to pickle file to load fast for further processing
logging.info('writing to geojson...')
write_geojson(freemove_raw, '../data/freemove/freemove_raw.geojson')
write_geojson(freemove_splitted, '../data/freemove/freemove_splitted.geojson')
write_geojson(freemove_smooth, '../data/freemove/freemove_smooth.geojson')
write_geojson(freemove_generalized, '../data/freemove/freemove_generalized.geojson')
write_geojson(freemove_smooth_generalized, '../data/freemove/freemove_smooth_generalized.geojson')

# Save point gdf as geojson
freemove_point_gdf = raw_full_trip_collection.to_point_gdf().reset_index()
write_geojson(freemove_point_gdf, '../data/freemove/freemove_raw_point.geojson')
freemove_smoothed_generalized_point = freemove_smooth_generalized_collection.to_point_gdf().reset_index()
write_geojson(freemove_smoothed_generalized_point, '../data/freemove/freemove_smooth_generalized_point.geojson')
logging.info('written to geojson.')
# Out:
# /usr/local/lib/python3.8/dist-packages/geopandas/io/file.py:362: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   pd.Int64Index,
# /usr/local/lib/python3.8/dist-packages/geopandas/io/file.py:362: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   pd.Int64Index,
